# %%
import google.generativeai as genai
import pandas as pd
import seaborn as sns


genai.configure(api_key="AIzaSyBkFIIVcgE4tFHyJqRfv2CAnwW0fNDzV0s")

# %%
for i, m in zip(range(5), genai.list_tuned_models()):
  print(m.name)
# Out:
# tunedModels/tuned-gemini-20250509041136-9lzfg3wqci39

# %%
model = genai.get_tuned_model(f'tunedModels/tuned-gemini-20250509041136-9lzfg3wqci39')

model
# Out:
# TunedModel(name='tunedModels/tuned-gemini-20250509041136-9lzfg3wqci39',
#            source_model='models/gemini-1.5-flash-001-tuning',
#            base_model='models/gemini-1.5-flash-001-tuning',
#            display_name='Tuned Gemini 20250509-041136',
#            description='',
#            temperature=1.0,
#            top_p=0.95,
#            top_k=64,
#            state=<State.ACTIVE: 2>,
#            create_time=datetime.datetime(2025, 5, 9, 8, 11, 48, 156759, tzinfo=datetime.timezone.utc),
#            update_time=datetime.datetime(2025, 5, 10, 2, 32, 2, 291236, tzinfo=datetime.timezone.utc),
#            tuning_task=TuningTask(start_time=datetime.datetime(2025, 5, 9, 8, 11, 52, 150188, tzinfo=datetime.timezone.utc),
#                                   complete_time=datetime.datetime(2025, 5, 10, 2, 32, 2, 291236, tzinfo=datetime.timezone.utc),
#                                   snapshots=[...],
# ...

# %%
snapshots = pd.DataFrame(model.tuning_task.snapshots)

sns.lineplot(data=snapshots, x = 'epoch', y='mean_loss')
# Out:
# <Axes: xlabel='epoch', ylabel='mean_loss'>

# %%
model = genai.GenerativeModel(model_name=f'tunedModels/tuned-gemini-20250509041136-9lzfg3wqci39')

# %%
result = model.generate_content('55')
result.text
# Out:
# "It's a tie."
